# %% [markdown]
# Aula 1

# %%
print("I Competição de Programação da Start")
# Out:
# I Competição de Programação da Start

# %%
ano = "II"

print(ano, "Competição de Programação da Start")
# Out:
# II Competição de Programação da Start

# %%
print(f"{ano} Competição de Programação da Start")

# %% [markdown]
# Aula 2

# %%
livro_ficcao = 10
livro_nficcao = 8
livro_infantil = 6

pontos_rodrigo = livro_ficcao + livro_nficcao + livro_infantil

print(f"Os pontos totais do Rodrigo são: {pontos_rodrigo}")

# %% [markdown]
# Desafio

# %%
livro_ficcao = 10
livro_nficcao = 8
livro_infantil = 6

pontos_ana = (2 * livro_ficcao) + (5 * livro_infantil)

pontos_rodrigo = 24

total_geral = pontos_ana + pontos_rodrigo

print(f"Os pontos totais da Ana são: {pontos_ana}")
print(f"A soma dos pontos de Rodrigo e Ana é: {total_geral}")

# %% [markdown]
# Aula 3

# %%
total_figurinhas = int(input("Digite o total de figurinhas: "))
numero_amigos = int(input("Digite o número de amigos: "))

figurinhas_amigos = total_figurinhas // (numero_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigos

print(f"João recebeu {figurinhas_joao} figurinhas.")

# %% [markdown]
# Desafio

# %%
total_figurinhas = int(input("Digite o total de figurinhas no envelope: "))
numero_amigos = int(input("Digite o número de amigos: "))
figurinhas_extras = int(input("Digite a quantidade de figurinhas extras: "))

novo_total = total_figurinhas + figurinhas_extras

figurinhas_amigos = novo_total // (numero_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigos

print(f"João recebeu {figurinhas_joao} figurinhas.")

# %% [markdown]
# Aula 4

# %%
numero_alunos = int(input("Digite a quantidade de alunos: "))
numero_monitores = int(input("Digite a quantidade de monitores: "))
resposta_positiva = "Pode ir"
resposta_negativa = "Não pode ir"

if numero_alunos + numero_monitores <= 50:
  print(resposta_positiva)
else:
  print(resposta_negativa)

# %% [markdown]
# Desafio

# %%
numero_alunos = int(input("Digite a quantidade de alunos: "))
numero_monitores = int(input("Digite a quantidade de monitores: "))
numero_professores = 8

total_pessoas = numero_alunos + numero_monitores + numero_professores

if total_pessoas <= 30:
    print("Pode ir")
else:
    print("Não pode ir")

# %% [markdown]
# Aula 5

# %%
p = int(input("Digite a posição da porta (0 ou 1):"))
r = int(input("Digite a posição da porta (0 ou 1):"))

if p==0 and r==0:
  print("C")
elif p==0 and r==1:
    print("C")
elif p==1 and r==1:
  print("A")
else:
  print("B")

# %% [markdown]
# Desafio

# %%
p = int(input("Digite a posição da portinha P (0 ou 1): "))
r = int(input("Digite a posição da portinha R (0 ou 1): "))
q = int(input("Digite a posição da portinha Q (0 ou 1): "))

if q == 1:
    print("D")

if p == 1:
    print("C")
else:
    if r == 1:
        print("B")
    else:
        print("A")

# %% [markdown]
# Aula 6

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2

  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)

  return idade_filho3, idade_maxima

calcula_idade_maior(68, 12, 30)

# %% [markdown]
# Desafio

# %%
def encontrar_maior_livro(l1, l2, l3, l4, l5):
    return max(l1, l2, l3, l4, l5)

livro1 = int(input("Digite as páginas do livro 1: "))
livro2 = int(input("Digite as páginas do livro 2: "))
livro3 = int(input("Digite as páginas do livro 3: "))
livro4 = int(input("Digite as páginas do livro 4: "))
livro5 = int(input("Digite as páginas do livro 5: "))

maior = encontrar_maior_livro(livro1, livro2, livro3, livro4, livro5)

print(maior)

# %% [markdown]
# Aula 7

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")

# numero_usuario = int(input("Digite um número para ver sua tabuada: "))
tabuada(12)
